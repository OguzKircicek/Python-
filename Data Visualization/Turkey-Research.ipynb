# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('C:/calismalarim/Indicators.csv')

# %%
hist_indicator = 'CO2 Emisyonu \(metric'
hist_country = 'TUR'

mask1 = data['IndicatorName'].str.contains(hist_indicator) 
mask2 = data['CountryCode'].str.contains(hist_country)


stage = data[mask1 & mask2]

# %%
plt.plot(stage['Year'].values, stage['Value'].values)


plt.xlabel('Year')
plt.ylabel(stage['IndicatorName'].iloc[0])


plt.title("Türkiye'de CO2 Emisyonu")


plt.axis([1959, 2015,0,5]) #0 dan 5 e kadar 1959-2015 yılları arası

plt.show()

# %%
hist_indicator = 'GDP per capita \(constant 2005'
hist_country = 'TUR'

mask1 = data['IndicatorName'].str.contains(hist_indicator) 
mask2 = data['CountryCode'].str.contains(hist_country)
gsyih_durum = data[mask1 & mask2]

# %%
plt.plot(gdp_stage['Year'].values, gdp_stage['Value'].values)

plt.xlabel('Yıl')
plt.ylabel(gdp_stage['IndicatorName'].iloc[0])

plt.title('TÜRKİYE GSYİH')


plt.show()

# %%
gdp_stage_trunc = gdp_stage[gdp_stage['Year'] < 2012] #neden 2012 oldu ? Çünkü Gsyih verileri 2014 e kadar ama co2 verileri 2011 e kadar aynı sayıda olmalıydı
print(len(gdp_stage_trunc))
print(len(stage))
# Out:
# 52
# 52

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig, axis = plt.subplots()
# Grid lines, Xticks, Xlabel, Ylabel

axis.yaxis.grid(True)
axis.set_title('CO2 Emisyonu vs GSYİH ',fontsize=10)
axis.set_xlabel(gdp_stage_trunc['IndicatorName'].iloc[0],fontsize=10)
axis.set_ylabel(stage['IndicatorName'].iloc[0],fontsize=10)

X = gdp_stage_trunc['Value']
Y = stage['Value']

axis.scatter(X, Y)
plt.show()
